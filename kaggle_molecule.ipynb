# %%
#!cp /content/kaggle.json ~/.kaggle/kaggle.json
# !cp /content/kaggle.json ~/.kaggle/kaggle.json
# !chmod 600 kaggle.json
from kaggle import KaggleApi
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-ec5fcc1d1e9f> in <module>()
#       1 get_ipython().system('cp /content/kaggle.json ~/.kaggle/kaggle.json')
# ----> 2 get_ipython().system('chmod 600 kaggle.json')
#       3 from kaggle import KaggleApi
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      82       kwargs.update({'also_return_output': True})
#      83
# ---> 84     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      85
#      86     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
# ...

# %%
api = KaggleApi()
api.authenticate()

# %%
files_to_download = ['dipole_moments.csv','magnetic_shielding_tensors.csv','mulliken_charges.csv','potential_energy.csv','scalar_coupling_contributions.csv','train.csv','test.csv','sample_submission.csv','structures.zip','structures.csv']
fil=api.competition_download_files('champs-scalar-coupling')

# %%
import pandas as pd
from pandas import DataFrame as df
import sklearn
import xgboost as xgb

# %%
import lightgbm

# %%
#dipole_moments = pd.read_csv('kaggle_molecule/dipole_moments.csv')

# %%
#magnetic_shielding_tensors = pd.read_csv('kaggle_molecule/magnetic_shielding_tensors.csv')

# %%
#mulliken_charges = pd.read_csv('kaggle_molecule/mulliken_charges.csv')

# %%
#potential_energy = pd.read_csv('kaggle_molecule/potential_energy.csv')

# %%
#scalar_coupling_contributions = pd.read_csv('kaggle_molecule/scalar_coupling_contributions.csv')

# %%
#structures = pd.read_csv('kaggle_molecule/structures.csv')

# %%
# !unzip train.csv.zip
# !unzip test.csv.zip

# %%
train = pd.read_csv('train.csv')

# %%
train

# %%
type_onehot = pd.get_dummies(train['type'])

# %%
#model = xgb.sklearn.XGBRegressor()
model = lightgbm.sklearn.LGBMRegressor()

# %%
model.fit(pd.concat([train[['atom_index_0','atom_index_1']],type_onehot],axis=1),train['scalar_coupling_constant'])
#model.fit(train[['atom_index_0','atom_index_1','type']],train['scalar_coupling_constant'])

# %%
test = pd.read_csv('test.csv')

# %%
test_type_onehot = pd.get_dummies(test['type'])

# %%
result = model.predict(pd.concat([test[['atom_index_0','atom_index_1']],test_type_onehot],axis=1))

# %%
submission = pd.concat([test[['id']],df(result,columns={"scalar_coupling_constant"})],axis=1)

# %%
df(submission).to_csv('submission.csv',index=False)

# %%
submission

# %%
# %matplotlib inline
from subprocess import check_output
print(check_output(["ls", "../input"]).decode("utf8"))
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-41-00c3e9ed6a11> in <module>()
#       1 get_ipython().magic('matplotlib inline')
#       2 from subprocess import check_output
# ----> 3 print(check_output(["ls", "../input"]).decode("utf8"))
#
# /usr/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     354
#     355     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 356                **kwargs).stdout
#     357
#     358
#
# /usr/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     436         if check and retcode:
#     437             raise CalledProcessError(retcode, process.args,
# --> 438                                      output=stdout, stderr=stderr)
#     439     return CompletedProcess(process.args, retcode, stdout, stderr)
#     440
#
# ...
